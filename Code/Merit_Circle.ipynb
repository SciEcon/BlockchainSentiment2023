# %% [markdown]
# # Import Data

# %%
import numpy as np

# %%
import pandas as pd

# %%
# Load the CSV file into a DataFrame with the correct encoding
mc= pd.read_csv('/content/Merit Circle - 💬 Chats & Voice──────────── - ╭💬・general-chat [942785405617582110].csv', encoding='ISO-8859-1')

# Assume mc is the DataFrame you want to remove unnamed columns from
mc = mc.loc[:, ~mc.columns.str.startswith('Unnamed:')]

# %%
mc.head()
# Out:
#        AuthorID         Author         Date_original       Date  \
# 0  3.035150e+17   filthyfawkes  2022/2/14 ä¸å9:12  2022/2/14
# 1  3.035150e+17   filthyfawkes  2022/2/14 ä¸å9:14  2022/2/14
# 2  3.035150e+17   filthyfawkes  2022/2/14 ä¸å9:14  2022/2/14
# 3  7.353470e+17  charless#7527  2022/2/14 ä¸å9:14  2022/2/14
# 4  8.716860e+17  Tueng.TV#8957  2022/2/14 ä¸å9:14  2022/2/14
#
#                            Content Attachments Reactions
# 0                    @Professor LP         NaN       NaN
# 1  @MC Scholar chat here with prof         NaN       NaN
# 2  if you can't speak in the lobby         NaN       NaN
# 3          Inspiration reveal prof         NaN       NaN
# 4                            Hello         NaN       NaN

# %%
mc.tail(1878)
# Out:
#            AuthorID           Author          Date_original       Date  \
# 34783  8.145010e+17         jaaanpol   2023/8/15 ä¸å9:54  2023/8/15
# 34784  8.145010e+17         jaaanpol   2023/8/15 ä¸å9:55  2023/8/15
# 34785  3.300080e+17    0xprofessorlp  2023/8/15 ä¸å11:17  2023/8/15
# 34786  8.145010e+17         jaaanpol  2023/8/16 ä¸å12:03  2023/8/16
# 34787  8.923340e+17           xrganz   2023/8/16 ä¸å1:13  2023/8/16
# ...             ...              ...                    ...        ...
# 36656  6.217500e+17   rajdeep_pathak   2023/9/25 ä¸å1:06  2023/9/25
# 36657  9.120800e+17           gadzho   2023/9/25 ä¸å2:06  2023/9/25
# 36658  1.025920e+18         tim3le55   2023/9/25 ä¸å2:28  2023/9/25
# 36659  6.217500e+17   rajdeep_pathak   2023/9/25 ä¸å2:45  2023/9/25
# 36660  9.671110e+17  yumikoklubx.bnb   2023/9/25 ä¸å2:50  2023/9/25
#
#                                                  Content Attachments Reactions
# 34783                   Yo! What do you mean Ga my fren?         NaN       NaN
# 34784        Yoo GM Gm! Excited for guild wars? ð¥ð¥         NaN       NaN
# 34785             GMMMM I am not that good with shooters         NaN       NaN
# 34786       Hahaha samedt they will carry us hahahahahha         NaN       NaN
# 34787                                                 Hi         NaN       NaN
# ...                                                  ...         ...       ...
# 36656                                       Good evening         NaN       NaN
# 36657      Hi all. Where is Crop bytes giveaway results?         NaN       NaN
# 36658    hello how can i play big time for Merit Circle?         NaN       NaN
# 36659  Any scholarships or games for mobile please te...         NaN       NaN
# 36660                                                 gm         NaN       NaN
#
# [1878 rows x 7 columns]

# %%
mc=mc[:34786]

# %%
mc
# Out:
#            AuthorID         Author          Date_original       Date  \
# 0      3.035150e+17   filthyfawkes   2022/2/14 ä¸å9:12  2022/2/14
# 1      3.035150e+17   filthyfawkes   2022/2/14 ä¸å9:14  2022/2/14
# 2      3.035150e+17   filthyfawkes   2022/2/14 ä¸å9:14  2022/2/14
# 3      7.353470e+17  charless#7527   2022/2/14 ä¸å9:14  2022/2/14
# 4      8.716860e+17  Tueng.TV#8957   2022/2/14 ä¸å9:14  2022/2/14
# ...             ...            ...                    ...        ...
# 34781  4.032740e+17       Obi#5683   2023/8/15 ä¸å8:22  2023/8/15
# 34782  2.802670e+17       dynosawr   2023/8/15 ä¸å8:38  2023/8/15
# 34783  8.145010e+17       jaaanpol   2023/8/15 ä¸å9:54  2023/8/15
# 34784  8.145010e+17       jaaanpol   2023/8/15 ä¸å9:55  2023/8/15
# 34785  3.300080e+17  0xprofessorlp  2023/8/15 ä¸å11:17  2023/8/15
#
#                                            Content Attachments Reactions
# 0                                    @Professor LP         NaN       NaN
# 1                  @MC Scholar chat here with prof         NaN       NaN
# 2                  if you can't speak in the lobby         NaN       NaN
# 3                          Inspiration reveal prof         NaN       NaN
# 4                                            Hello         NaN       NaN
# ...                                            ...         ...       ...
# 34781                       Okay perfect, thanks !         NaN       NaN
# 34782                        gm gm Orange fam ð§¡         NaN       NaN
# 34783             Yo! What do you mean Ga my fren?         NaN       NaN
# 34784  Yoo GM Gm! Excited for guild wars? ð¥ð¥         NaN       NaN
# 34785       GMMMM I am not that good with shooters         NaN       NaN
#
# [34786 rows x 7 columns]

# %% [markdown]
# # Text Processing

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import re

# Download stopwords and stemmer
nltk.download('stopwords')
nltk.download('punkt')

# Define the preprocessing function
stop_words = set(stopwords.words('english'))
def preprocess_text(text):
    # Check if text is NaN
    if pd.isna(text):
        return ""

    # Convert to lowercase
    text = text.lower()

    # Remove URLs
    text = re.sub(r'http\S+', '', text)

    # Remove non-alphabetic characters
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    # Tokenize the text
    words = word_tokenize(text)

    # Remove stop words and punctuation
    words = [word for word in words if word not in stop_words and word.isalpha()]

    # Join the remaining words into a string
    text = ' '.join(words)

    return text

# Apply the preprocessing function to the 'Content' column
mc['Preprocessed'] = mc['Content'].apply(preprocess_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
mc.tail()
# Out:
#            AuthorID         Author          Date_original       Date  \
# 34781  4.032740e+17       Obi#5683   2023/8/15 ä¸å8:22  2023/8/15
# 34782  2.802670e+17       dynosawr   2023/8/15 ä¸å8:38  2023/8/15
# 34783  8.145010e+17       jaaanpol   2023/8/15 ä¸å9:54  2023/8/15
# 34784  8.145010e+17       jaaanpol   2023/8/15 ä¸å9:55  2023/8/15
# 34785  3.300080e+17  0xprofessorlp  2023/8/15 ä¸å11:17  2023/8/15
#
#                                            Content Attachments Reactions  \
# 34781                       Okay perfect, thanks !         NaN       NaN
# 34782                        gm gm Orange fam ð§¡         NaN       NaN
# 34783             Yo! What do you mean Ga my fren?         NaN       NaN
# 34784  Yoo GM Gm! Excited for guild wars? ð¥ð¥         NaN       NaN
# 34785       GMMMM I am not that good with shooters         NaN       NaN
#
#                        Preprocessed
# 34781           okay perfect thanks
# 34782              gm gm orange fam
# 34783               yo mean ga fren
# 34784  yoo gm gm excited guild wars
# 34785           gmmmm good shooters

# %%
# Save the cleaned DataFrame to a new CSV file
mc.to_csv('cleaned_discord_mc_governance.csv', index=False)

# %% [markdown]
# # Sentiment Analysis (VADER)

# %%
! pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.10/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2023.7.22)

# %%
mc.dropna(subset=['Date'], inplace=True)

# %%
mc.tail()
# Out:
#            AuthorID         Author          Date_original       Date  \
# 34781  4.032740e+17       Obi#5683   2023/8/15 ä¸å8:22  2023/8/15
# 34782  2.802670e+17       dynosawr   2023/8/15 ä¸å8:38  2023/8/15
# 34783  8.145010e+17       jaaanpol   2023/8/15 ä¸å9:54  2023/8/15
# 34784  8.145010e+17       jaaanpol   2023/8/15 ä¸å9:55  2023/8/15
# 34785  3.300080e+17  0xprofessorlp  2023/8/15 ä¸å11:17  2023/8/15
#
#                                            Content Attachments Reactions  \
# 34781                       Okay perfect, thanks !         NaN       NaN
# 34782                        gm gm Orange fam ð§¡         NaN       NaN
# 34783             Yo! What do you mean Ga my fren?         NaN       NaN
# 34784  Yoo GM Gm! Excited for guild wars? ð¥ð¥         NaN       NaN
# 34785       GMMMM I am not that good with shooters         NaN       NaN
#
#                        Preprocessed
# 34781           okay perfect thanks
# 34782              gm gm orange fam
# 34783               yo mean ga fren
# 34784  yoo gm gm excited guild wars
# 34785           gmmmm good shooters

# %%
MC= mc
MC.head()
# Out:
#        AuthorID         Author         Date_original       Date  \
# 0  3.035150e+17   filthyfawkes  2022/2/14 ä¸å9:12  2022/2/14
# 1  3.035150e+17   filthyfawkes  2022/2/14 ä¸å9:14  2022/2/14
# 2  3.035150e+17   filthyfawkes  2022/2/14 ä¸å9:14  2022/2/14
# 3  7.353470e+17  charless#7527  2022/2/14 ä¸å9:14  2022/2/14
# 4  8.716860e+17  Tueng.TV#8957  2022/2/14 ä¸å9:14  2022/2/14
#
#                            Content Attachments Reactions  \
# 0                    @Professor LP         NaN       NaN
# 1  @MC Scholar chat here with prof         NaN       NaN
# 2  if you can't speak in the lobby         NaN       NaN
# 3          Inspiration reveal prof         NaN       NaN
# 4                            Hello         NaN       NaN
#
#               Preprocessed
# 0             professor lp
# 1     mc scholar chat prof
# 2         cant speak lobby
# 3  inspiration reveal prof
# 4                    hello

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Initialize the sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Convert the 'Date' column to a datetime object and set it as the index

MC['Date'] = pd.to_datetime(MC['Date'], errors='coerce')
MC.set_index('Date', inplace=True)

# Define a function to compute the sentiment score for each day
def daily_sentiment_score(text):
    sentiment = analyzer.polarity_scores(text)
    return sentiment['compound']

# Compute the daily sentiment score using resample and apply
mc_daily = MC['Preprocessed'].resample('D').apply(lambda x: x.apply(daily_sentiment_score).mean())

# %%
mc_daily
# Out:
# Date
# 2022-02-14    0.082079
# 2022-02-15    0.086300
# 2022-02-16    0.030227
# 2022-02-17    0.205917
# 2022-02-18    0.069763
#                 ...
# 2023-08-11    0.113057
# 2023-08-12    0.024477
# 2023-08-13    0.057190
# 2023-08-14    0.321223
# 2023-08-15    0.163078
# Freq: D, Name: Preprocessed, Length: 548, dtype: float64

# %%
mc_daily_sentiment = mc_daily.to_frame(name='Sentiment Score').reset_index()

# %%
mc_daily_sentiment.columns
# Out:
# Index(['Date', 'Sentiment Score'], dtype='object')

# %%
mc_daily_sentiment.head()
# Out:
#         Date  Sentiment Score
# 0 2022-02-14         0.082079
# 1 2022-02-15         0.086300
# 2 2022-02-16         0.030227
# 3 2022-02-17         0.205917
# 4 2022-02-18         0.069763

# %%
mc_daily_sentiment['Sentiment Score'].fillna(0.000000, inplace=True)

# %%
mc_daily_sentiment
# Out:
#           Date  Sentiment Score
# 0   2022-02-14         0.082079
# 1   2022-02-15         0.086300
# 2   2022-02-16         0.030227
# 3   2022-02-17         0.205917
# 4   2022-02-18         0.069763
# ..         ...              ...
# 543 2023-08-11         0.113057
# 544 2023-08-12         0.024477
# 545 2023-08-13         0.057190
# 546 2023-08-14         0.321223
# 547 2023-08-15         0.163078
#
# [548 rows x 2 columns]

# %%
mc_daily_sentiment.to_csv('sentiment_discord_mc_governance.csv', index=False)

# %%
import plotly.graph_objs as go

# Create a line graph using Plotly
fig = go.Figure()

# Add a line trace to the figure
fig.add_trace(go.Scatter(x=mc_daily_sentiment['Date'], y=mc_daily_sentiment['Sentiment Score'], mode='lines'))

# Customize the layout of the figure
fig.update_layout(title='Merit Circle Discord Daily Sentiment Score', xaxis_title='Date', yaxis_title='Sentiment Score')

# Display the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7375151d-28ae-45e7-911f-e555dfe874bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7375151d-28ae-45e7-911f-e555dfe874bf")) {                    Plotly.newPlot(                        "7375151d-28ae-45e7-911f-e555dfe874bf",                        [{"mode":"lines","x":["2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-19T00:00:00","2022-02-20T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-26T00:00:00","2022-02-27T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-05T00:00:00","2022-03-06T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-12T00:00:00","2022-03-13T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-19T00:00:00","2022-03-20T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-26T00:00:00","2022-03-27T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00","2022-03-31T00:00:00","2022-04-01T00:00:00","2022-04-02T00:00:00","2022-04-03T00:00:00","2022-04-04T00:00:00","2022-04-05T00:00:00","2022-04-06T00:00:00","2022-04-07T00:00:00","2022-04-08T00:00:00","2022-04-09T00:00:00","2022-04-10T00:00:00","2022-04-11T00:00:00","2022-04-12T00:00:00","2022-04-13T00:00:00","2022-04-14T00:00:00","2022-04-15T00:00:00","2022-04-16T00:00:00","2022-04-17T00:00:00","2022-04-18T00:00:00","2022-04-19T00:00:00","2022-04-20T00:00:00","2022-04-21T00:00:00","2022-04-22T00:00:00","2022-04-23T00:00:00","2022-04-24T00:00:00","2022-04-25T00:00:00","2022-04-26T00:00:00","2022-04-27T00:00:00","2022-04-28T00:00:00","2022-04-29T00:00:00","2022-04-30T00:00:00","2022-05-01T00:00:00","2022-05-02T00:00:00","2022-05-03T00:00:00","2022-05-04T00:00:00","2022-05-05T00:00:00","2022-05-06T00:00:00","2022-05-07T00:00:00","2022-05-08T00:00:00","2022-05-09T00:00:00","2022-05-10T00:00:00","2022-05-11T00:00:00","2022-05-12T00:00:00","2022-05-13T00:00:00","2022-05-14T00:00:00","2022-05-15T00:00:00","2022-05-16T00:00:00","2022-05-17T00:00:00","2022-05-18T00:00:00","2022-05-19T00:00:00","2022-05-20T00:00:00","2022-05-21T00:00:00","2022-05-22T00:00:00","2022-05-23T00:00:00","2022-05-24T00:00:00","2022-05-25T00:00:00","2022-05-26T00:00:00","2022-05-27T00:00:00","2022-05-28T00:00:00","2022-05-29T00:00:00","2022-05-30T00:00:00","2022-05-31T00:00:00","2022-06-01T00:00:00","2022-06-02T00:00:00","2022-06-03T00:00:00","2022-06-04T00:00:00","2022-06-05T00:00:00","2022-06-06T00:00:00","2022-06-07T00:00:00","2022-06-08T00:00:00","2022-06-09T00:00:00","2022-06-10T00:00:00","2022-06-11T00:00:00","2022-06-12T00:00:00","2022-06-13T00:00:00","2022-06-14T00:00:00","2022-06-15T00:00:00","2022-06-16T00:00:00","2022-06-17T00:00:00","2022-06-18T00:00:00","2022-06-19T00:00:00","2022-06-20T00:00:00","2022-06-21T00:00:00","2022-06-22T00:00:00","2022-06-23T00:00:00","2022-06-24T00:00:00","2022-06-25T00:00:00","2022-06-26T00:00:00","2022-06-27T00:00:00","2022-06-28T00:00:00","2022-06-29T00:00:00","2022-06-30T00:00:00","2022-07-01T00:00:00","2022-07-02T00:00:00","2022-07-03T00:00:00","2022-07-04T00:00:00","2022-07-05T00:00:00","2022-07-06T00:00:00","2022-07-07T00:00:00","2022-07-08T00:00:00","2022-07-09T00:00:00","2022-07-10T00:00:00","2022-07-11T00:00:00","2022-07-12T00:00:00","2022-07-13T00:00:00","2022-07-14T00:00:00","2022-07-15T00:00:00","2022-07-16T00:00:00","2022-07-17T00:00:00","2022-07-18T00:00:00","2022 ...

# %%
positive_count = len(mc_daily_sentiment[mc_daily_sentiment['Sentiment Score'] > 0])
negative_count = len(mc_daily_sentiment[mc_daily_sentiment['Sentiment Score'] < 0])

# %%
import plotly.express as px

# Calculate positive and negative sentiment counts
positive_count = (mc_daily_sentiment['Sentiment Score'] > 0).sum()
negative_count = (mc_daily_sentiment['Sentiment Score'] < 0).sum()

# Create a dataframe for histogram
hist_mc = pd.DataFrame({
    'Sentiment': ['Positive', 'Negative'],
    'Count': [positive_count, negative_count]
})

# Create a plotly histogram
fig = px.histogram(hist_mc, x='Sentiment', y='Count', color='Sentiment',
                   title='Merit Circle Discord Sentiment Distribution')

# Set y-axis label
fig.update_layout(yaxis_title='Count (days)')

# Add count number on each bar
fig.update_traces(texttemplate='%{y}', textposition='outside')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c6751527-3509-4216-bfca-768d618d2acd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6751527-3509-4216-bfca-768d618d2acd")) {                    Plotly.newPlot(                        "c6751527-3509-4216-bfca-768d618d2acd",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Sentiment=%{x}\u003cbr\u003esum of Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Positive","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Positive","offsetgroup":"Positive","orientation":"v","showlegend":true,"x":["Positive"],"xaxis":"x","y":[456],"yaxis":"y","type":"histogram","textposition":"outside","texttemplate":"%{y}"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Sentiment=%{x}\u003cbr\u003esum of Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Negative","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Negative","offsetgroup":"Negative","orientation":"v","showlegend":true,"x":["Negative"],"xaxis":"x","y":[17],"yaxis":"y","type":"histogram","textposition":"outside","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size ...

# %%
# Calculate overall statistics on the sentiment scores
overall_sentiment_stats = mc_daily_sentiment['Sentiment Score'].describe()

# Output overall sentiment statistics
print("Overall Sentiment Statistics:")
print(overall_sentiment_stats)
# Out:
# Overall Sentiment Statistics:
# count    548.000000
# mean       0.141720
# std        0.111625
# min       -0.278700
# 25%        0.064887
# 50%        0.143399
# 75%        0.208525
# max        0.893400
# Name: Sentiment Score, dtype: float64

# %% [markdown]
# ## User-Sentiment

# %%
# Create a new column to store sentiment scores
MC['Sentiment_Score'] = 0.0

# Group the data based on AuthorID
grouped = MC.groupby('AuthorID')

# Iterate through each group
for author, group in grouped:
    # Perform sentiment analysis on the content of each group and store sentiment scores
    sentiment_scores = []
    for content in group['Content']:
        # Check if the content is a string; if not, convert it to a string
        if not isinstance(content, str):
            content = str(content)
        sentiment = analyzer.polarity_scores(content)
        sentiment_scores.append(sentiment['compound'])

    # Assign the average sentiment score to all rows in each group
    MC.loc[group.index, 'Sentiment_Score'] = sum(sentiment_scores) / len(sentiment_scores)

# Now, your DataFrame will have a new column named 'Sentiment_Score' containing the average sentiment score for each user
# You can further analyze or visualize these sentiment scores as needed

# %%
# Calculate the number of messages per user
message_count_per_user = MC['AuthorID'].value_counts()

# Calculate user count
user_count = len(message_count_per_user)

# Calculate 25th, median (50th), 75th, minimum, and maximum percentiles of message counts
message_count_percentiles = message_count_per_user.describe(percentiles=[0.25, 0.5, 0.75])

# Calculate the mean number of messages per user
mean_messages_per_user = message_count_per_user.mean()

# Calculate the minimum and maximum message counts
min_message_count = message_count_per_user.min()
max_message_count = message_count_per_user.max()

# Calculate the distribution of average sentiment scores per user's message
sentiment_scores_per_user = MC.groupby('AuthorID')['Sentiment_Score'].mean()

# Print the results
print("User Count:", user_count)
print("25th Percentile of Message Counts:", message_count_percentiles['25%'])
print("Median (50th Percentile) of Message Counts:", message_count_percentiles['50%'])
print("75th Percentile of Message Counts:", message_count_percentiles['75%'])
print("Minimum Message Count:", min_message_count)
print("Maximum Message Count:", max_message_count)
print("Mean Number of Messages per User:", mean_messages_per_user)
print("Distribution of Average Sentiment Scores per User's Message:")
print(sentiment_scores_per_user)
# Out:
# User Count: 2287
# 25th Percentile of Message Counts: 1.0
# Median (50th Percentile) of Message Counts: 3.0
# 75th Percentile of Message Counts: 8.0
# Minimum Message Count: 1
# Maximum Message Count: 1827
# Mean Number of Messages per User: 15.210319195452557
# Distribution of Average Sentiment Scores per User's Message:
# AuthorID
# 8.584770e+16    0.161183
# 1.050630e+17    0.115913
# 1.102280e+17   -0.021770
# 1.126720e+17    0.082354
# 1.277860e+17    0.102067
#                   ...
# 1.128750e+18    0.169563
# 1.128770e+18    0.475300
# 1.131170e+18    0.263880
# 1.133800e+18    0.000000
# 1.135520e+18    0.000000
# Name: Sentiment_Score, Length: 2287, dtype: float64

# %%
# Convert the Series into a DataFrame with a named column
sentiment_scores_df = sentiment_scores_per_user.reset_index()
sentiment_scores_df.columns = ['AuthorID', 'Average_Sentiment_Score']

# Print the resulting DataFrame
sentiment_scores_df
# Out:
#           AuthorID  Average_Sentiment_Score
# 0     8.584770e+16                 0.161183
# 1     1.050630e+17                 0.115913
# 2     1.102280e+17                -0.021770
# 3     1.126720e+17                 0.082354
# 4     1.277860e+17                 0.102067
# ...            ...                      ...
# 2282  1.128750e+18                 0.169563
# 2283  1.128770e+18                 0.475300
# 2284  1.131170e+18                 0.263880
# 2285  1.133800e+18                 0.000000
# 2286  1.135520e+18                 0.000000
#
# [2287 rows x 2 columns]

# %%
# Count the number of records with sentiment score equal to 0
count_zero_sentiment = (sentiment_scores_df['Average_Sentiment_Score'] == 0).sum()

# Print the count
print("Number of records with sentiment score equal to 0:", count_zero_sentiment)
# Out:
# Number of records with sentiment score equal to 0: 501

# %%
# Drop rows where Average_Sentiment_Score is 0
sentiment_scores_df_new = sentiment_scores_df[sentiment_scores_df['Average_Sentiment_Score'] != 0]

# Print the resulting DataFrame
sentiment_scores_df_new
# Out:
#           AuthorID  Average_Sentiment_Score
# 0     8.584770e+16                 0.161183
# 1     1.050630e+17                 0.115913
# 2     1.102280e+17                -0.021770
# 3     1.126720e+17                 0.082354
# 4     1.277860e+17                 0.102067
# ...            ...                      ...
# 2280  1.127320e+18                 0.659700
# 2281  1.128600e+18                 0.169563
# 2282  1.128750e+18                 0.169563
# 2283  1.128770e+18                 0.475300
# 2284  1.131170e+18                 0.263880
#
# [1786 rows x 2 columns]

# %%
import plotly.express as px

# Assuming you have a DataFrame named sentiment_scores_df_new
# If you haven't already created it, please follow the previous response

# Create a histogram
fig = px.histogram(sentiment_scores_df_new, x='Average_Sentiment_Score', title='Distribution of Average Sentiment Scores per User\'s Message')

# Show the histogram
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="73470d5c-de50-47a3-82d4-ff8188d991e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73470d5c-de50-47a3-82d4-ff8188d991e4")) {                    Plotly.newPlot(                        "73470d5c-de50-47a3-82d4-ff8188d991e4",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Average_Sentiment_Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[0.16118333333333332,0.1159125,-0.02177037037037037,0.08235365853658537,0.10206666666666668,0.311045,0.006600000000000004,0.11149225342558679,0.1695,0.43640000000000007,0.22897000000000003,0.09352791666666667,0.307925,0.09500800000000001,0.1695,0.5591666666666667,0.33702499999999996,-0.1503285714285714,0.4404,0.16490253164556964,0.31949333333333335,0.4404,0.7184,0.24654034090909088,0.11184396995082457,0.2114905,-0.100475,0.228796524141943,0.8586,0.1851556818181818,0.0647937172774869,0.7287333333333333,0.3844,0.693325,0.19488,0.7287333333333333,0.1851556818181818,0.6835,0.1659948308184785,0.25974567901234585,0.31146344696969697,0.3096,0.307925,0.04096815873015873,0.021100000000000004,-0.11246,0.7184,0.1159125,0.23774999999999996,-0.1503285714285714,0.0019579571759259264,0.26589999999999997,0.16779666666666668,0.45005,0.007492592592592592,-0.02177037037037037,0.21187439480401526,0.011238888888888889,-0.11246,-0.02177037037037037,0.1468,0.3267666666666667,0.307925,0.006166666666666667,0.24654034090909088,0.1851556818181818,0.1695,0.10860258333333332,0.04067676549140391,0.08970872148862953,-0.010276089717822356,0.082275,0.07996074526397491,0.1695,0.054542857142857136,0.1159125,0.13767776937470003,0.07278703074866312,0.04502827380952381,0.2463953125,0.021287500000000004,-0.3155,-0.025168194444444444,-0.05159596501689525,0.15788351010101012,0.09866842302333682,-0.03827333333333333,0.6476,0.025631538452926345,0.16346192374416246,0.08808,0.19488,0.2072,-0.045470000000000003,0.005718849206349207,-0.030561468404091352,0.29263666666666666,0.04569705049362403,0.15411237878787878,0.1695625,0.08808,0.28620312005068105,0.1159125,0.1539625,0.08353835125448028,0.06873652597402598,0.307925,0.1663,0.00925,0.4382499999999999,-0.02177037037037037,0.1522243059821318,0.06474692307692309,0.24876666666666666,0.1159125,-0.02580955882352941,0.1851556818181818,0.4972768292682927,0.09279367816091956,0.06526553595986528,0.1695,0.0057612686567164225,0.20533750000000006,0.307925,0.1159125,0.18019333333333332,0.17412637147335427,-0.02177037037037037,0.12130687622789782,0.13721533333333333,0.1591,0.1159125,0.24457999999999996,0.17412106509042824,0.1695625,0.10859387755102042,0.09519230769230771,0.1806,0.0185,0.038362291666666666,0.13813333333333333,0.08415714285714286,0.09519230769230771,0.23774999999999993,0.17860092262483776,0.03780488450817867,0.1851556818181818,0.1159125,-0.125575,0.3844,0.9001,0.0411375,0.1695,0.07454979885057471,0.19488,0.3966382102272727,0.307925,0.080778125,0.09519230769230771,0.08808,-0.02177037037037037,0.2537333333333333,-0.010040340909090907,0.5689145833333333,0.026334999999999997,0.26388,0.42189999999999994,0.19488,0.16226969814491637,0.0925778409090909,0.10153791666666666,0.17731942810899684,0.14184285714285713,0.011704444444444443,0.1695,0.0006235804738562133,0.02811626506024096,0.25974567901234585,0.1851556818181818,0.0647937172774869,0.15553320707070706,-0.009012037037037037,0.25974567901234585,-0.01078613153594771,0.058119921875,-0.089968,0.5643142857142857,0.307925,0.17201176470588234,0.011238888888888889,0.25060000000000004,0.307925,0.032095603448275875,0.3105,-0.001649719416386083,-0.000 ...

# %%
# Define the bins, excluding 0 as a separate interval
bins = [-1.0, -0.5, 0.0, 0.5, 1.0]
hist, bin_edges = pd.cut(sentiment_scores_df_new['Average_Sentiment_Score'], bins, right=False, retbins=True)

# Create a DataFrame to display the frequency table
frequency_table = pd.value_counts(hist, sort=False).reset_index()
frequency_table.columns = ['Sentiment_Score_Range', 'Frequency']

# Calculate the proportion of each bin
total_records = len(sentiment_scores_df_new)
frequency_table['Proportion'] = frequency_table['Frequency'] / total_records

# Display the frequency table
print(frequency_table)
# Out:
#   Sentiment_Score_Range  Frequency  Proportion
# 0          [-1.0, -0.5)          1    0.000560
# 1           [-0.5, 0.0)        337    0.188690
# 2            [0.0, 0.5)       1364    0.763718
# 3            [0.5, 1.0)         84    0.047032

# %% [markdown]
# # Discord Volume

# %%
# Group the discord messages by day and count the number of discord messages in each day
daily_discord_count = MC['Content'].resample('D').count()

# Print the daily discord message count
print(daily_discord_count)
# Out:
# Date
# 2022-02-14     270
# 2022-02-15       6
# 2022-02-16     506
# 2022-02-17      18
# 2022-02-18    1743
#               ...
# 2023-08-11      23
# 2023-08-12      12
# 2023-08-13      10
# 2023-08-14      48
# 2023-08-15      40
# Freq: D, Name: Content, Length: 548, dtype: int64

# %%
daily_discord_count = daily_discord_count.to_frame(name='Discord Volume').reset_index()

# %%
daily_discord_count
# Out:
#           Date  Discord Volume
# 0   2022-02-14             270
# 1   2022-02-15               6
# 2   2022-02-16             506
# 3   2022-02-17              18
# 4   2022-02-18            1743
# ..         ...             ...
# 543 2023-08-11              23
# 544 2023-08-12              12
# 545 2023-08-13              10
# 546 2023-08-14              48
# 547 2023-08-15              40
#
# [548 rows x 2 columns]

# %%
daily_discord_count.to_csv('discord_volume_mc_governance.csv', index=False)

# %%
import plotly.graph_objs as go

# Create a line graph using Plotly
fig = go.Figure()

# Add a line trace to the figure
fig.add_trace(go.Scatter(x=daily_discord_count['Date'], y=daily_discord_count['Discord Volume'], mode='lines'))

# Customize the layout of the figure
fig.update_layout(title='Merit Circle Discord Daily Message Volume', xaxis_title='Date', yaxis_title='Discord Message Volume')

# Display the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9697be25-8e29-4774-9760-10ae6908b1b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9697be25-8e29-4774-9760-10ae6908b1b8")) {                    Plotly.newPlot(                        "9697be25-8e29-4774-9760-10ae6908b1b8",                        [{"mode":"lines","x":["2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-19T00:00:00","2022-02-20T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-26T00:00:00","2022-02-27T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-05T00:00:00","2022-03-06T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-12T00:00:00","2022-03-13T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-19T00:00:00","2022-03-20T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-26T00:00:00","2022-03-27T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00","2022-03-31T00:00:00","2022-04-01T00:00:00","2022-04-02T00:00:00","2022-04-03T00:00:00","2022-04-04T00:00:00","2022-04-05T00:00:00","2022-04-06T00:00:00","2022-04-07T00:00:00","2022-04-08T00:00:00","2022-04-09T00:00:00","2022-04-10T00:00:00","2022-04-11T00:00:00","2022-04-12T00:00:00","2022-04-13T00:00:00","2022-04-14T00:00:00","2022-04-15T00:00:00","2022-04-16T00:00:00","2022-04-17T00:00:00","2022-04-18T00:00:00","2022-04-19T00:00:00","2022-04-20T00:00:00","2022-04-21T00:00:00","2022-04-22T00:00:00","2022-04-23T00:00:00","2022-04-24T00:00:00","2022-04-25T00:00:00","2022-04-26T00:00:00","2022-04-27T00:00:00","2022-04-28T00:00:00","2022-04-29T00:00:00","2022-04-30T00:00:00","2022-05-01T00:00:00","2022-05-02T00:00:00","2022-05-03T00:00:00","2022-05-04T00:00:00","2022-05-05T00:00:00","2022-05-06T00:00:00","2022-05-07T00:00:00","2022-05-08T00:00:00","2022-05-09T00:00:00","2022-05-10T00:00:00","2022-05-11T00:00:00","2022-05-12T00:00:00","2022-05-13T00:00:00","2022-05-14T00:00:00","2022-05-15T00:00:00","2022-05-16T00:00:00","2022-05-17T00:00:00","2022-05-18T00:00:00","2022-05-19T00:00:00","2022-05-20T00:00:00","2022-05-21T00:00:00","2022-05-22T00:00:00","2022-05-23T00:00:00","2022-05-24T00:00:00","2022-05-25T00:00:00","2022-05-26T00:00:00","2022-05-27T00:00:00","2022-05-28T00:00:00","2022-05-29T00:00:00","2022-05-30T00:00:00","2022-05-31T00:00:00","2022-06-01T00:00:00","2022-06-02T00:00:00","2022-06-03T00:00:00","2022-06-04T00:00:00","2022-06-05T00:00:00","2022-06-06T00:00:00","2022-06-07T00:00:00","2022-06-08T00:00:00","2022-06-09T00:00:00","2022-06-10T00:00:00","2022-06-11T00:00:00","2022-06-12T00:00:00","2022-06-13T00:00:00","2022-06-14T00:00:00","2022-06-15T00:00:00","2022-06-16T00:00:00","2022-06-17T00:00:00","2022-06-18T00:00:00","2022-06-19T00:00:00","2022-06-20T00:00:00","2022-06-21T00:00:00","2022-06-22T00:00:00","2022-06-23T00:00:00","2022-06-24T00:00:00","2022-06-25T00:00:00","2022-06-26T00:00:00","2022-06-27T00:00:00","2022-06-28T00:00:00","2022-06-29T00:00:00","2022-06-30T00:00:00","2022-07-01T00:00:00","2022-07-02T00:00:00","2022-07-03T00:00:00","2022-07-04T00:00:00","2022-07-05T00:00:00","2022-07-06T00:00:00","2022-07-07T00:00:00","2022-07-08T00:00:00","2022-07-09T00:00:00","2022-07-10T00:00:00","2022-07-11T00:00:00","2022-07-12T00:00:00","2022-07-13T00:00:00","2022-07-14T00:00:00","2022-07-15T00:00:00","2022-07-16T00:00:00","2022-07-17T00:00:00","2022-07-18T00:00:00","2022 ...
