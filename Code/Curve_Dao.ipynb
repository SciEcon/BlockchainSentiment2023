# %% [markdown]
# # Import Data

# %%
import numpy as np

# %%
import pandas as pd

# %%
# Load the CSV file into a DataFrame with the correct encoding
crv= pd.read_csv('/content/Curve Finance - General - curve-governance [745257323487953036].csv', encoding='ISO-8859-1')

# Assume crv is the DataFrame you want to remove unnamed columns from
crv = crv.loc[:, ~crv.columns.str.startswith('Unnamed:')]

# %%
crv.head()
# Out:
#        AuthorID        Author         Date_original       Date  \
# 0  1.850000e+17  charliecurve  2020/8/18 ä¸å8:33  2020/8/18
# 1  1.850000e+17  charliecurve  2020/8/18 ä¸å8:34  2020/8/18
# 2  1.850000e+17  charliecurve  2020/8/18 ä¸å8:34  2020/8/18
# 3  1.850000e+17  charliecurve  2020/8/18 ä¸å8:36  2020/8/18
# 4  2.330000e+17    ronchiporc  2020/8/18 ä¸å8:36  2020/8/18
#
#                                              Content Attachments Reactions
# 0  I also like the idea of having a deposit fee i...         NaN       NaN
# 1        Withdrawal fees seem to work well for yearn         NaN       NaN
# 2  Haven't really seen people have issues with it...         NaN       NaN
# 3  I think there is good support for a gold pool ...         NaN       NaN
# 4                                             thanks         NaN       NaN

# %%
crv.tail(90)
# Out:
#           AuthorID             Author          Date_original       Date  \
# 8772  7.610000e+17            node.cm    2023/8/5 ä¸å9:16   2023/8/5
# 8773  7.620000e+17           mimaklas   2023/8/15 ä¸å6:34  2023/8/15
# 8774  7.390000e+17             chanho  2023/8/17 ä¸å10:21  2023/8/17
# 8775  7.390000e+17             chanho  2023/8/17 ä¸å10:22  2023/8/17
# 8776  7.620000e+17           mimaklas    2023/9/3 ä¸å7:43   2023/9/3
# ...            ...                ...                    ...        ...
# 8857  3.980000e+17    blockenthusiast   2023/9/18 ä¸å3:30  2023/9/18
# 8858  7.620000e+17           mimaklas   2023/9/18 ä¸å3:30  2023/9/18
# 8859  4.260000e+17       pilotvietnam   2023/9/18 ä¸å3:46  2023/9/18
# 8860  1.150000e+18  alexbasedao_50859   2023/9/21 ä¸å9:08  2023/9/21
# 8861  9.690000e+17          mattimost   2023/9/23 ä¸å7:17  2023/9/23
#
#                                                 Content Attachments  Reactions
# ...

# %%
crv=crv[:8774]

# %%
crv
# Out:
#           AuthorID        Author         Date_original       Date  \
# 0     1.850000e+17  charliecurve  2020/8/18 ä¸å8:33  2020/8/18
# 1     1.850000e+17  charliecurve  2020/8/18 ä¸å8:34  2020/8/18
# 2     1.850000e+17  charliecurve  2020/8/18 ä¸å8:34  2020/8/18
# 3     1.850000e+17  charliecurve  2020/8/18 ä¸å8:36  2020/8/18
# 4     2.330000e+17    ronchiporc  2020/8/18 ä¸å8:36  2020/8/18
# ...            ...           ...                   ...        ...
# 8769  6.870000e+17      ogidogie   2023/8/4 ä¸å7:08   2023/8/4
# 8770  7.610000e+17       node.cm   2023/8/5 ä¸å9:10   2023/8/5
# 8771  7.610000e+17       node.cm   2023/8/5 ä¸å9:10   2023/8/5
# 8772  7.610000e+17       node.cm   2023/8/5 ä¸å9:16   2023/8/5
# 8773  7.620000e+17      mimaklas  2023/8/15 ä¸å6:34  2023/8/15
#
#                                                 Content Attachments Reactions
# 0     I also like the idea of having a deposit fee i...         NaN       NaN
# ...

# %% [markdown]
# # Text Processing

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import re

# Download stopwords and stemmer
nltk.download('stopwords')
nltk.download('punkt')

# Define the preprocessing function
stop_words = set(stopwords.words('english'))
def preprocess_text(text):
    # Check if text is NaN
    if pd.isna(text):
        return ""

    # Convert to lowercase
    text = text.lower()

    # Remove URLs
    text = re.sub(r'http\S+', '', text)

    # Remove non-alphabetic characters
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    # Tokenize the text
    words = word_tokenize(text)

    # Remove stop words and punctuation
    words = [word for word in words if word not in stop_words and word.isalpha()]

    # Join the remaining words into a string
    text = ' '.join(words)

    return text

# Apply the preprocessing function to the 'Content' column
crv['Preprocessed'] = crv['Content'].apply(preprocess_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
crv.tail()
# Out:
#           AuthorID    Author         Date_original       Date  \
# 8769  6.870000e+17  ogidogie   2023/8/4 ä¸å7:08   2023/8/4
# 8770  7.610000e+17   node.cm   2023/8/5 ä¸å9:10   2023/8/5
# 8771  7.610000e+17   node.cm   2023/8/5 ä¸å9:10   2023/8/5
# 8772  7.610000e+17   node.cm   2023/8/5 ä¸å9:16   2023/8/5
# 8773  7.620000e+17  mimaklas  2023/8/15 ä¸å6:34  2023/8/15
#
#                                                 Content Attachments Reactions  \
# 8769  Hey guys! Iâve submitted my request via your...         NaN       NaN
# 8770  Hello. guys ,I am Chiranjeev, a Business Devel...         NaN       NaN
# 8771  It would be really great if someone from team ...         NaN       NaN
# 8772                                              @team         NaN       NaN
# 8773  https://gov.curve.fi/t/whitelist-the-prisma-da...         NaN       NaN
#
#                                            Preprocessed
# 8769  hey guys ive submitted request via forum since...
# ...

# %%
# Save the cleaned DataFrame to a new CSV file
crv.to_csv('cleaned_discord_crv_governance.csv', index=False)

# %% [markdown]
# # Sentiment Analysis (VADER)

# %%
! pip install vaderSentiment
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 4.9 MB/s eta 0:00:00
# ...

# %%
crv.dropna(subset=['Date'], inplace=True)

# %%
crv.tail()
# Out:
#           AuthorID    Author         Date_original       Date  \
# 8769  6.870000e+17  ogidogie   2023/8/4 ä¸å7:08   2023/8/4
# 8770  7.610000e+17   node.cm   2023/8/5 ä¸å9:10   2023/8/5
# 8771  7.610000e+17   node.cm   2023/8/5 ä¸å9:10   2023/8/5
# 8772  7.610000e+17   node.cm   2023/8/5 ä¸å9:16   2023/8/5
# 8773  7.620000e+17  mimaklas  2023/8/15 ä¸å6:34  2023/8/15
#
#                                                 Content Attachments Reactions  \
# 8769  Hey guys! Iâve submitted my request via your...         NaN       NaN
# 8770  Hello. guys ,I am Chiranjeev, a Business Devel...         NaN       NaN
# 8771  It would be really great if someone from team ...         NaN       NaN
# 8772                                              @team         NaN       NaN
# 8773  https://gov.curve.fi/t/whitelist-the-prisma-da...         NaN       NaN
#
#                                            Preprocessed
# 8769  hey guys ive submitted request via forum since...
# ...

# %%
CRV= crv
CRV.head()
# Out:
#        AuthorID        Author         Date_original       Date  \
# 0  1.850000e+17  charliecurve  2020/8/18 ä¸å8:33  2020/8/18
# 1  1.850000e+17  charliecurve  2020/8/18 ä¸å8:34  2020/8/18
# 2  1.850000e+17  charliecurve  2020/8/18 ä¸å8:34  2020/8/18
# 3  1.850000e+17  charliecurve  2020/8/18 ä¸å8:36  2020/8/18
# 4  2.330000e+17    ronchiporc  2020/8/18 ä¸å8:36  2020/8/18
#
#                                              Content Attachments Reactions  \
# 0  I also like the idea of having a deposit fee i...         NaN       NaN
# 1        Withdrawal fees seem to work well for yearn         NaN       NaN
# 2  Haven't really seen people have issues with it...         NaN       NaN
# 3  I think there is good support for a gold pool ...         NaN       NaN
# 4                                             thanks         NaN       NaN
#
#                                         Preprocessed
# 0  also like idea deposit fee cases pools much li...
# ...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Initialize the sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Convert the 'Date' column to a datetime object and set it as the index

CRV['Date'] = pd.to_datetime(CRV['Date'], errors='coerce')
CRV.set_index('Date', inplace=True)

# Define a function to compute the sentiment score for each day
def daily_sentiment_score(text):
    sentiment = analyzer.polarity_scores(text)
    return sentiment['compound']

# Compute the daily sentiment score using resample and apply
crv_daily = CRV['Preprocessed'].resample('D').apply(lambda x: x.apply(daily_sentiment_score).mean())

# %%
crv_daily
# Out:
# Date
# 2020-08-18    0.247408
# 2020-08-19    0.233642
# 2020-08-20    0.195448
# 2020-08-21    0.329100
# 2020-08-22    0.305358
#                 ...
# 2023-08-11         NaN
# 2023-08-12         NaN
# 2023-08-13         NaN
# 2023-08-14         NaN
# 2023-08-15    0.000000
# Freq: D, Name: Preprocessed, Length: 1093, dtype: float64

# %%
crv_daily_sentiment = crv_daily.to_frame(name='Sentiment Score').reset_index()

# %%
crv_daily_sentiment.columns
# Out:
# Index(['Date', 'Sentiment Score'], dtype='object')

# %%
crv_daily_sentiment.head()
# Out:
#         Date  Sentiment Score
# 0 2020-08-18         0.247408
# 1 2020-08-19         0.233642
# 2 2020-08-20         0.195448
# 3 2020-08-21         0.329100
# 4 2020-08-22         0.305358

# %%
crv_daily_sentiment['Sentiment Score'].fillna(0.000000, inplace=True)

# %%
crv_daily_sentiment
# Out:
#            Date  Sentiment Score
# 0    2020-08-18         0.247408
# 1    2020-08-19         0.233642
# 2    2020-08-20         0.195448
# 3    2020-08-21         0.329100
# 4    2020-08-22         0.305358
# ...         ...              ...
# 1088 2023-08-11         0.000000
# 1089 2023-08-12         0.000000
# 1090 2023-08-13         0.000000
# 1091 2023-08-14         0.000000
# 1092 2023-08-15         0.000000
#
# [1093 rows x 2 columns]

# %%
crv_daily_sentiment.to_csv('sentiment_discord_crv_governance.csv', index=False)

# %%
import plotly.graph_objs as go

# Create a line graph using Plotly
fig = go.Figure()

# Add a line trace to the figure
fig.add_trace(go.Scatter(x=crv_daily_sentiment['Date'], y=crv_daily_sentiment['Sentiment Score'], mode='lines'))

# Customize the layout of the figure
fig.update_layout(title='Curve Discord Daily Sentiment Score', xaxis_title='Date', yaxis_title='Sentiment Score')

# Display the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
positive_count = len(crv_daily_sentiment[crv_daily_sentiment['Sentiment Score'] > 0])
negative_count = len(crv_daily_sentiment[crv_daily_sentiment['Sentiment Score'] < 0])

# %%
import plotly.express as px

# Calculate positive and negative sentiment counts
positive_count = (crv_daily_sentiment['Sentiment Score'] > 0).sum()
negative_count = (crv_daily_sentiment['Sentiment Score'] < 0).sum()

# Create a dataframe for histogram
hist_crv = pd.DataFrame({
    'Sentiment': ['Positive', 'Negative'],
    'Count': [positive_count, negative_count]
})

# Create a plotly histogram
fig = px.histogram(hist_crv, x='Sentiment', y='Count', color='Sentiment',
                   title='Curve Discord Sentiment Distribution')

# Set y-axis label
fig.update_layout(yaxis_title='Count (days)')

# Add count number on each bar
fig.update_traces(texttemplate='%{y}', textposition='outside')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Calculate overall statistics on the sentiment scores
overall_sentiment_stats = crv_daily_sentiment['Sentiment Score'].describe()

# Output overall sentiment statistics
print("Overall Sentiment Statistics:")
print(overall_sentiment_stats)
# Out:
# Overall Sentiment Statistics:
# count    1093.000000
# mean        0.126055
# std         0.200950
# min        -0.542300
# 25%         0.000000
# 50%         0.000000
# 75%         0.205811
# max         0.987400
# Name: Sentiment Score, dtype: float64

# %% [markdown]
# # Discord Volume

# %%
# Group the discord messages by day and count the number of discord messages in each day
daily_discord_count = CRV['Content'].resample('D').count()

# Print the daily discord message count
print(daily_discord_count)
# Out:
# Date
# 2020-08-18    72
# 2020-08-19    48
# 2020-08-20    94
# 2020-08-21    55
# 2020-08-22    38
#               ..
# 2023-08-11     0
# 2023-08-12     0
# 2023-08-13     0
# 2023-08-14     0
# 2023-08-15     1
# Freq: D, Name: Content, Length: 1093, dtype: int64

# %%
daily_discord_count = daily_discord_count.to_frame(name='Discord Volume').reset_index()

# %%
daily_discord_count
# Out:
#            Date  Discord Volume
# 0    2020-08-18              72
# 1    2020-08-19              48
# 2    2020-08-20              94
# 3    2020-08-21              55
# 4    2020-08-22              38
# ...         ...             ...
# 1088 2023-08-11               0
# 1089 2023-08-12               0
# 1090 2023-08-13               0
# 1091 2023-08-14               0
# 1092 2023-08-15               1
#
# [1093 rows x 2 columns]

# %%
daily_discord_count.to_csv('discord_volume_crv_governance.csv', index=False)

# %%
import plotly.graph_objs as go

# Create a line graph using Plotly
fig = go.Figure()

# Add a line trace to the figure
fig.add_trace(go.Scatter(x=daily_discord_count['Date'], y=daily_discord_count['Discord Volume'], mode='lines'))

# Customize the layout of the figure
fig.update_layout(title='Curve Discord Daily Message Volume', xaxis_title='Date', yaxis_title='Discord Message Volume')

# Display the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
