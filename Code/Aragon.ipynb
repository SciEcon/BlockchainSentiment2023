# %% [markdown]
# # Import Data

# %%
import numpy as np

# %%
import pandas as pd

# %%
# Load the CSV file into a DataFrame with the correct encoding
ant= pd.read_csv('/content/Aragon 🦅 - DAO Builders - dao-builders-chat [1036975360551702568].csv', encoding='ISO-8859-1')

# Assume ant is the DataFrame you want to remove unnamed columns from
ant = ant.loc[:, ~ant.columns.str.startswith('Unnamed:')]

# %%
ant.head()
# Out:
#        AuthorID         Author           Date_original        Date  \
# 0  7.961480e+17  charliecavecc  2022/11/20 ä¸å12:44  2022/11/20
# 1  9.068500e+17       istreams   2022/11/20 ä¸å8:49  2022/11/20
# 2  8.076440e+17  shawnzywonzie   2022/11/20 ä¸å9:53  2022/11/20
# 3  8.076440e+17  shawnzywonzie   2022/11/20 ä¸å9:53  2022/11/20
# 4  9.068500e+17       istreams   2022/11/20 ä¸å9:58  2022/11/20
#
#                                              Content Attachments Reactions
# 0                                                 Hi         NaN       NaN
# 1  Heyyy I'm interested in building a Dao but don...         NaN       NaN
# 2  Nice, well you came to the right place ð Wh...         NaN       NaN
# 3                Hey @Charlie Cave "CC" How goes it?         NaN       NaN
# 4  What you mean? I see the Dao as a social justi...         NaN       NaN

# %%
ant.tail(105)
# Out:
#          AuthorID               Author          Date_original       Date  \
# 698  1.120710e+18             mosh1257   2023/8/15 ä¸å4:23  2023/8/15
# 699  7.293270e+17  IharDabmrouski#0125   2023/8/15 ä¸å4:25  2023/8/15
# 700  1.134480e+18      themalteseeagle   2023/8/15 ä¸å7:44  2023/8/15
# 701  1.812620e+17            kharmabum  2023/8/15 ä¸å11:56  2023/8/15
# 702  9.889930e+17            lunaduong   2023/8/16 ä¸å3:04  2023/8/16
# ..            ...                  ...                    ...        ...
# 798  8.689950e+17        samanthamarin   2023/9/22 ä¸å7:12  2023/9/22
# 799  2.103790e+17             plopmenz   2023/9/23 ä¸å3:08  2023/9/23
# 800  4.383590e+17               buzech   2023/9/24 ä¸å9:33  2023/9/24
# 801  1.134480e+18      themalteseeagle   2023/9/25 ä¸å8:40  2023/9/25
# 802  4.383590e+17               buzech   2023/9/25 ä¸å9:23  2023/9/25
#
#                                                Content Attachments Reactions
# 698                                Is working good now         NaN       NaN
# 699                                                yes         NaN       NaN
# 700  Glad everything iw working for you now. For fu...         NaN       NaN
# 701  I posted a ? re implementing a local UBI progr...         NaN       NaN
# 702                                  Started a thread.         NaN       NaN
# ..                                                 ...         ...       ...
# 798                                  Started a thread.         NaN       NaN
# 799                                  Started a thread.         NaN       NaN
# 800       Any open discuss group for Aragon investors?         NaN       NaN
# 801  The ANT Token is strictly a governance token. ...         NaN       NaN
# 802                         This not live chat discuss         NaN       NaN
#
# [105 rows x 7 columns]

# %%
ant=ant[:702]

# %%
ant
# Out:
#          AuthorID               Author           Date_original        Date  \
# 0    7.961480e+17        charliecavecc  2022/11/20 ä¸å12:44  2022/11/20
# 1    9.068500e+17             istreams   2022/11/20 ä¸å8:49  2022/11/20
# 2    8.076440e+17        shawnzywonzie   2022/11/20 ä¸å9:53  2022/11/20
# 3    8.076440e+17        shawnzywonzie   2022/11/20 ä¸å9:53  2022/11/20
# 4    9.068500e+17             istreams   2022/11/20 ä¸å9:58  2022/11/20
# ..            ...                  ...                     ...         ...
# 697  1.120710e+18             mosh1257    2023/8/15 ä¸å4:22   2023/8/15
# 698  1.120710e+18             mosh1257    2023/8/15 ä¸å4:23   2023/8/15
# 699  7.293270e+17  IharDabmrouski#0125    2023/8/15 ä¸å4:25   2023/8/15
# 700  1.134480e+18      themalteseeagle    2023/8/15 ä¸å7:44   2023/8/15
# 701  1.812620e+17            kharmabum   2023/8/15 ä¸å11:56   2023/8/15
#
#                                                Content Attachments Reactions
# 0                                                   Hi         NaN       NaN
# 1    Heyyy I'm interested in building a Dao but don...         NaN       NaN
# 2    Nice, well you came to the right place ð Wh...         NaN       NaN
# 3                  Hey @Charlie Cave "CC" How goes it?         NaN       NaN
# 4    What you mean? I see the Dao as a social justi...         NaN       NaN
# ..                                                 ...         ...       ...
# 697                                  Itâs node error         NaN       NaN
# 698                                Is working good now         NaN       NaN
# 699                                                yes         NaN       NaN
# 700  Glad everything iw working for you now. For fu...         NaN       NaN
# 701  I posted a ? re implementing a local UBI progr...         NaN       NaN
#
# [702 rows x 7 columns]

# %% [markdown]
# # Text Processing

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import re

# Download stopwords and stemmer
nltk.download('stopwords')
nltk.download('punkt')

# Define the preprocessing function
stop_words = set(stopwords.words('english'))
def preprocess_text(text):
    # Check if text is NaN
    if pd.isna(text):
        return ""

    # Convert to lowercase
    text = text.lower()

    # Remove URLs
    text = re.sub(r'http\S+', '', text)

    # Remove non-alphabetic characters
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    # Tokenize the text
    words = word_tokenize(text)

    # Remove stop words and punctuation
    words = [word for word in words if word not in stop_words and word.isalpha()]

    # Join the remaining words into a string
    text = ' '.join(words)

    return text

# Apply the preprocessing function to the 'Content' column
ant['Preprocessed'] = ant['Content'].apply(preprocess_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
ant.tail()
# Out:
#          AuthorID               Author          Date_original       Date  \
# 697  1.120710e+18             mosh1257   2023/8/15 ä¸å4:22  2023/8/15
# 698  1.120710e+18             mosh1257   2023/8/15 ä¸å4:23  2023/8/15
# 699  7.293270e+17  IharDabmrouski#0125   2023/8/15 ä¸å4:25  2023/8/15
# 700  1.134480e+18      themalteseeagle   2023/8/15 ä¸å7:44  2023/8/15
# 701  1.812620e+17            kharmabum  2023/8/15 ä¸å11:56  2023/8/15
#
#                                                Content Attachments Reactions  \
# 697                                  Itâs node error         NaN       NaN
# 698                                Is working good now         NaN       NaN
# 699                                                yes         NaN       NaN
# 700  Glad everything iw working for you now. For fu...         NaN       NaN
# 701  I posted a ? re implementing a local UBI progr...         NaN       NaN
#
#                                           Preprocessed
# 697                                         node error
# 698                                       working good
# 699                                                yes
# 700  glad everything iw working future reference su...
# 701  posted implementing local ubi program would lo...

# %%
# Save the cleaned DataFrame to a new CSV file
ant.to_csv('cleaned_discord_ant_governance.csv', index=False)

# %% [markdown]
# # Sentiment Analysis (VADER)

# %%
! pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2023.7.22)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
ant.dropna(subset=['Date'], inplace=True)

# %%
ant.tail()
# Out:
#          AuthorID               Author          Date_original       Date  \
# 697  1.120710e+18             mosh1257   2023/8/15 ä¸å4:22  2023/8/15
# 698  1.120710e+18             mosh1257   2023/8/15 ä¸å4:23  2023/8/15
# 699  7.293270e+17  IharDabmrouski#0125   2023/8/15 ä¸å4:25  2023/8/15
# 700  1.134480e+18      themalteseeagle   2023/8/15 ä¸å7:44  2023/8/15
# 701  1.812620e+17            kharmabum  2023/8/15 ä¸å11:56  2023/8/15
#
#                                                Content Attachments Reactions  \
# 697                                  Itâs node error         NaN       NaN
# 698                                Is working good now         NaN       NaN
# 699                                                yes         NaN       NaN
# 700  Glad everything iw working for you now. For fu...         NaN       NaN
# 701  I posted a ? re implementing a local UBI progr...         NaN       NaN
#
#                                           Preprocessed
# 697                                         node error
# 698                                       working good
# 699                                                yes
# 700  glad everything iw working future reference su...
# 701  posted implementing local ubi program would lo...

# %%
ANT= ant
ANT.head()
# Out:
#        AuthorID         Author           Date_original        Date  \
# 0  7.961480e+17  charliecavecc  2022/11/20 ä¸å12:44  2022/11/20
# 1  9.068500e+17       istreams   2022/11/20 ä¸å8:49  2022/11/20
# 2  8.076440e+17  shawnzywonzie   2022/11/20 ä¸å9:53  2022/11/20
# 3  8.076440e+17  shawnzywonzie   2022/11/20 ä¸å9:53  2022/11/20
# 4  9.068500e+17       istreams   2022/11/20 ä¸å9:58  2022/11/20
#
#                                              Content Attachments Reactions  \
# 0                                                 Hi         NaN       NaN
# 1  Heyyy I'm interested in building a Dao but don...         NaN       NaN
# 2  Nice, well you came to the right place ð Wh...         NaN       NaN
# 3                Hey @Charlie Cave "CC" How goes it?         NaN       NaN
# 4  What you mean? I see the Dao as a social justi...         NaN       NaN
#
#                                         Preprocessed
# 0                                                 hi
# 1   heyyy im interested building dao dont know start
# 2       nice well came right place kind dao starting
# 3                           hey charlie cave cc goes
# 4  mean see dao social justice dao similar assang...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Initialize the sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Convert the 'Date' column to a datetime object and set it as the index

ANT['Date'] = pd.to_datetime(ANT['Date'], errors='coerce')
ANT.set_index('Date', inplace=True)

# Define a function to compute the sentiment score for each day
def daily_sentiment_score(text):
    sentiment = analyzer.polarity_scores(text)
    return sentiment['compound']

# Compute the daily sentiment score using resample and apply
ant_daily = ANT['Preprocessed'].resample('D').apply(lambda x: x.apply(daily_sentiment_score).mean())

# %%
ant_daily
# Out:
# Date
# 2022-11-20    0.288957
# 2022-11-21    0.483450
# 2022-11-22    0.641450
# 2022-11-23    0.000000
# 2022-11-24         NaN
#                 ...
# 2023-08-11    0.150120
# 2023-08-12    0.542300
# 2023-08-13         NaN
# 2023-08-14    0.065275
# 2023-08-15    0.204908
# Freq: D, Name: Preprocessed, Length: 269, dtype: float64

# %%
ant_daily_sentiment = ant_daily.to_frame(name='Sentiment Score').reset_index()

# %%
ant_daily_sentiment.columns
# Out:
# Index(['Date', 'Sentiment Score'], dtype='object')

# %%
ant_daily_sentiment.head()
# Out:
#         Date  Sentiment Score
# 0 2022-11-20         0.288957
# 1 2022-11-21         0.483450
# 2 2022-11-22         0.641450
# 3 2022-11-23         0.000000
# 4 2022-11-24              NaN

# %%
ant_daily_sentiment['Sentiment Score'].fillna(0.000000, inplace=True)

# %%
ant_daily_sentiment
# Out:
#           Date  Sentiment Score
# 0   2022-11-20         0.288957
# 1   2022-11-21         0.483450
# 2   2022-11-22         0.641450
# 3   2022-11-23         0.000000
# 4   2022-11-24         0.000000
# ..         ...              ...
# 264 2023-08-11         0.150120
# 265 2023-08-12         0.542300
# 266 2023-08-13         0.000000
# 267 2023-08-14         0.065275
# 268 2023-08-15         0.204908
#
# [269 rows x 2 columns]

# %%
ant_daily_sentiment.to_csv('sentiment_discord_ant_governance.csv', index=False)

# %%
import plotly.graph_objs as go

# Create a line graph using Plotly
fig = go.Figure()

# Add a line trace to the figure
fig.add_trace(go.Scatter(x=ant_daily_sentiment['Date'], y=ant_daily_sentiment['Sentiment Score'], mode='lines'))

# Customize the layout of the figure
fig.update_layout(title='Aragon Discord Daily Sentiment Score', xaxis_title='Date', yaxis_title='Sentiment Score')

# Display the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b0b020d1-a128-4a92-b20e-2bd3b087eacd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0b020d1-a128-4a92-b20e-2bd3b087eacd")) {                    Plotly.newPlot(                        "b0b020d1-a128-4a92-b20e-2bd3b087eacd",                        [{"mode":"lines","x":["2022-11-20T00:00:00","2022-11-21T00:00:00","2022-11-22T00:00:00","2022-11-23T00:00:00","2022-11-24T00:00:00","2022-11-25T00:00:00","2022-11-26T00:00:00","2022-11-27T00:00:00","2022-11-28T00:00:00","2022-11-29T00:00:00","2022-11-30T00:00:00","2022-12-01T00:00:00","2022-12-02T00:00:00","2022-12-03T00:00:00","2022-12-04T00:00:00","2022-12-05T00:00:00","2022-12-06T00:00:00","2022-12-07T00:00:00","2022-12-08T00:00:00","2022-12-09T00:00:00","2022-12-10T00:00:00","2022-12-11T00:00:00","2022-12-12T00:00:00","2022-12-13T00:00:00","2022-12-14T00:00:00","2022-12-15T00:00:00","2022-12-16T00:00:00","2022-12-17T00:00:00","2022-12-18T00:00:00","2022-12-19T00:00:00","2022-12-20T00:00:00","2022-12-21T00:00:00","2022-12-22T00:00:00","2022-12-23T00:00:00","2022-12-24T00:00:00","2022-12-25T00:00:00","2022-12-26T00:00:00","2022-12-27T00:00:00","2022-12-28T00:00:00","2022-12-29T00:00:00","2022-12-30T00:00:00","2022-12-31T00:00:00","2023-01-01T00:00:00","2023-01-02T00:00:00","2023-01-03T00:00:00","2023-01-04T00:00:00","2023-01-05T00:00:00","2023-01-06T00:00:00","2023-01-07T00:00:00","2023-01-08T00:00:00","2023-01-09T00:00:00","2023-01-10T00:00:00","2023-01-11T00:00:00","2023-01-12T00:00:00","2023-01-13T00:00:00","2023-01-14T00:00:00","2023-01-15T00:00:00","2023-01-16T00:00:00","2023-01-17T00:00:00","2023-01-18T00:00:00","2023-01-19T00:00:00","2023-01-20T00:00:00","2023-01-21T00:00:00","2023-01-22T00:00:00","2023-01-23T00:00:00","2023-01-24T00:00:00","2023-01-25T00:00:00","2023-01-26T00:00:00","2023-01-27T00:00:00","2023-01-28T00:00:00","2023-01-29T00:00:00","2023-01-30T00:00:00","2023-01-31T00:00:00","2023-02-01T00:00:00","2023-02-02T00:00:00","2023-02-03T00:00:00","2023-02-04T00:00:00","2023-02-05T00:00:00","2023-02-06T00:00:00","2023-02-07T00:00:00","2023-02-08T00:00:00","2023-02-09T00:00:00","2023-02-10T00:00:00","2023-02-11T00:00:00","2023-02-12T00:00:00","2023-02-13T00:00:00","2023-02-14T00:00:00","2023-02-15T00:00:00","2023-02-16T00:00:00","2023-02-17T00:00:00","2023-02-18T00:00:00","2023-02-19T00:00:00","2023-02-20T00:00:00","2023-02-21T00:00:00","2023-02-22T00:00:00","2023-02-23T00:00:00","2023-02-24T00:00:00","2023-02-25T00:00:00","2023-02-26T00:00:00","2023-02-27T00:00:00","2023-02-28T00:00:00","2023-03-01T00:00:00","2023-03-02T00:00:00","2023-03-03T00:00:00","2023-03-04T00:00:00","2023-03-05T00:00:00","2023-03-06T00:00:00","2023-03-07T00:00:00","2023-03-08T00:00:00","2023-03-09T00:00:00","2023-03-10T00:00:00","2023-03-11T00:00:00","2023-03-12T00:00:00","2023-03-13T00:00:00","2023-03-14T00:00:00","2023-03-15T00:00:00","2023-03-16T00:00:00","2023-03-17T00:00:00","2023-03-18T00:00:00","2023-03-19T00:00:00","2023-03-20T00:00:00","2023-03-21T00:00:00","2023-03-22T00:00:00","2023-03-23T00:00:00","2023-03-24T00:00:00","2023-03-25T00:00:00","2023-03-26T00:00:00","2023-03-27T00:00:00","2023-03-28T00:00:00","2023-03-29T00:00:00","2023-03-30T00:00:00","2023-03-31T00:00:00","2023-04-01T00:00:00","2023-04-02T00:00:00","2023-04-03T00:00:00","2023-04-04T00:00:00","2023-04-05T00:00:00","2023-04-06T00:00:00","2023-04-07T00:00:00","2023-04-08T00:00:00","2023-04-09T00:00:00","2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-14T00:00:00","2023-04-15T00:00:00","2023-04-16T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-22T00:00:00","2023-04-23T00:00:00","2023 ...

# %%
positive_count = len(ant_daily_sentiment[ant_daily_sentiment['Sentiment Score'] > 0])
negative_count = len(ant_daily_sentiment[ant_daily_sentiment['Sentiment Score'] < 0])

# %%
import plotly.express as px

# Calculate positive and negative sentiment counts
positive_count = (ant_daily_sentiment['Sentiment Score'] > 0).sum()
negative_count = (ant_daily_sentiment['Sentiment Score'] < 0).sum()

# Create a dataframe for histogram
hist_ant = pd.DataFrame({
    'Sentiment': ['Positive', 'Negative'],
    'Count': [positive_count, negative_count]
})

# Create a plotly histogram
fig = px.histogram(hist_ant, x='Sentiment', y='Count', color='Sentiment',
                   title='Aragon Discord Sentiment Distribution')

# Set y-axis label
fig.update_layout(yaxis_title='Count (days)')

# Add count number on each bar
fig.update_traces(texttemplate='%{y}', textposition='outside')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e35a806b-2085-4ca0-aa99-ca3185fed5f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e35a806b-2085-4ca0-aa99-ca3185fed5f9")) {                    Plotly.newPlot(                        "e35a806b-2085-4ca0-aa99-ca3185fed5f9",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Sentiment=%{x}\u003cbr\u003esum of Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Positive","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Positive","offsetgroup":"Positive","orientation":"v","showlegend":true,"x":["Positive"],"xaxis":"x","y":[115],"yaxis":"y","type":"histogram","textposition":"outside","texttemplate":"%{y}"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Sentiment=%{x}\u003cbr\u003esum of Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Negative","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Negative","offsetgroup":"Negative","orientation":"v","showlegend":true,"x":["Negative"],"xaxis":"x","y":[13],"yaxis":"y","type":"histogram","textposition":"outside","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size ...

# %%
# Calculate overall statistics on the sentiment scores
overall_sentiment_stats = ant_daily_sentiment['Sentiment Score'].describe()

# Output overall sentiment statistics
print("Overall Sentiment Statistics:")
print(overall_sentiment_stats)
# Out:
# Overall Sentiment Statistics:
# count    269.000000
# mean       0.145271
# std        0.239143
# min       -0.340000
# 25%        0.000000
# 50%        0.000000
# 75%        0.262625
# max        0.983700
# Name: Sentiment Score, dtype: float64

# %% [markdown]
# ## User-Sentiment

# %%
# Create a new column to store sentiment scores
ANT['Sentiment_Score'] = 0.0

# Group the data based on AuthorID
grouped = ANT.groupby('AuthorID')

# Iterate through each group
for author, group in grouped:
    # Perform sentiment analysis on the content of each group and store sentiment scores
    sentiment_scores = []
    for content in group['Content']:
        # Check if the content is a string; if not, convert it to a string
        if not isinstance(content, str):
            content = str(content)
        sentiment = analyzer.polarity_scores(content)
        sentiment_scores.append(sentiment['compound'])

    # Assign the average sentiment score to all rows in each group
    ANT.loc[group.index, 'Sentiment_Score'] = sum(sentiment_scores) / len(sentiment_scores)

# Now, your DataFrame will have a new column named 'Sentiment_Score' containing the average sentiment score for each user
# You can further analyze or visualize these sentiment scores as needed

# %%
# Calculate the number of messages per user
message_count_per_user = ANT['AuthorID'].value_counts()

# Calculate user count
user_count = len(message_count_per_user)

# Calculate 25th, median (50th), 75th, minimum, and maximum percentiles of message counts
message_count_percentiles = message_count_per_user.describe(percentiles=[0.25, 0.5, 0.75])

# Calculate the mean number of messages per user
mean_messages_per_user = message_count_per_user.mean()

# Calculate the minimum and maximum message counts
min_message_count = message_count_per_user.min()
max_message_count = message_count_per_user.max()

# Calculate the distribution of average sentiment scores per user's message
sentiment_scores_per_user = ANT.groupby('AuthorID')['Sentiment_Score'].mean()

# Print the results
print("User Count:", user_count)
print("25th Percentile of Message Counts:", message_count_percentiles['25%'])
print("Median (50th Percentile) of Message Counts:", message_count_percentiles['50%'])
print("75th Percentile of Message Counts:", message_count_percentiles['75%'])
print("Minimum Message Count:", min_message_count)
print("Maximum Message Count:", max_message_count)
print("Mean Number of Messages per User:", mean_messages_per_user)
print("Distribution of Average Sentiment Scores per User's Message:")
print(sentiment_scores_per_user)
# Out:
# User Count: 170
# 25th Percentile of Message Counts: 1.0
# Median (50th Percentile) of Message Counts: 2.0
# 75th Percentile of Message Counts: 4.0
# Minimum Message Count: 1
# Maximum Message Count: 75
# Mean Number of Messages per User: 4.129411764705883
# Distribution of Average Sentiment Scores per User's Message:
# AuthorID
# 1.419960e+17    0.340922
# 1.746480e+17    0.207539
# 1.812620e+17    0.516500
# 2.103790e+17    0.169365
# 2.307100e+17    0.105576
#                   ...
# 1.118520e+18    0.072083
# 1.119010e+18    0.710400
# 1.120710e+18    0.516500
# 1.121200e+18    0.861100
# 1.134480e+18    0.516500
# Name: Sentiment_Score, Length: 170, dtype: float64

# %%
# Convert the Series into a DataFrame with a named column
sentiment_scores_df = sentiment_scores_per_user.reset_index()
sentiment_scores_df.columns = ['AuthorID', 'Average_Sentiment_Score']

# Print the resulting DataFrame
sentiment_scores_df
# Out:
#          AuthorID  Average_Sentiment_Score
# 0    1.419960e+17                 0.340922
# 1    1.746480e+17                 0.207539
# 2    1.812620e+17                 0.516500
# 3    2.103790e+17                 0.169365
# 4    2.307100e+17                 0.105576
# ..            ...                      ...
# 165  1.118520e+18                 0.072083
# 166  1.119010e+18                 0.710400
# 167  1.120710e+18                 0.516500
# 168  1.121200e+18                 0.861100
# 169  1.134480e+18                 0.516500
#
# [170 rows x 2 columns]

# %%
# Count the number of records with sentiment score equal to 0
count_zero_sentiment = (sentiment_scores_df['Average_Sentiment_Score'] == 0).sum()

# Print the count
print("Number of records with sentiment score equal to 0:", count_zero_sentiment)
# Out:
# Number of records with sentiment score equal to 0: 18

# %%
# Drop rows where Average_Sentiment_Score is 0
sentiment_scores_df_new = sentiment_scores_df[sentiment_scores_df['Average_Sentiment_Score'] != 0]

# Print the resulting DataFrame
sentiment_scores_df_new
# Out:
#          AuthorID  Average_Sentiment_Score
# 0    1.419960e+17                 0.340922
# 1    1.746480e+17                 0.207539
# 2    1.812620e+17                 0.516500
# 3    2.103790e+17                 0.169365
# 4    2.307100e+17                 0.105576
# ..            ...                      ...
# 165  1.118520e+18                 0.072083
# 166  1.119010e+18                 0.710400
# 167  1.120710e+18                 0.516500
# 168  1.121200e+18                 0.861100
# 169  1.134480e+18                 0.516500
#
# [152 rows x 2 columns]

# %%
import plotly.express as px

# Assuming you have a DataFrame named sentiment_scores_df_new
# If you haven't already created it, please follow the previous response

# Create a histogram
fig = px.histogram(sentiment_scores_df_new, x='Average_Sentiment_Score', title='Distribution of Average Sentiment Scores per User\'s Message')

# Show the histogram
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ae04d632-8167-4692-abb1-50d7de7250cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae04d632-8167-4692-abb1-50d7de7250cc")) {                    Plotly.newPlot(                        "ae04d632-8167-4692-abb1-50d7de7250cc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Average_Sentiment_Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[0.3409222222222222,0.2075390243902439,0.5165000000000001,0.169364536463109,0.10557611940298509,0.19065789473684214,0.49560000000000004,0.4588,-0.027251842105263137,0.16704080653642356,0.10557611940298509,0.49560000000000004,0.44588,0.8442,0.1055761194029851,0.10557611940298509,0.4036765884861407,0.16088805970149253,0.03660000000000001,0.27136666666666664,0.0386,0.32695,-0.13396666666666665,0.10557611940298509,0.03661930970149254,0.9368,-0.23835,0.2821880597014925,-0.13396666666666665,0.5789,-0.02929850671976107,0.3182,0.2752361111111111,0.07691296455424276,0.17873951219512196,0.21505000000000002,0.1763,0.2075390243902439,0.2075390243902439,0.27368047855958305,0.2075390243902439,-0.06638694029850746,0.23031298245614037,0.10557611940298509,0.2999522999276427,0.45336,0.3415281179138322,0.9219,0.45336,0.15685537313432837,0.9128,0.06465714285714284,0.9366,0.45336,0.3409222222222222,0.10557611940298509,0.10557611940298509,0.10557611940298509,-0.17252499999999998,0.4893464912280702,0.19065789473684214,0.17445,0.19065789473684214,0.45879999999999993,0.012248,0.19065789473684214,0.10557611940298509,-0.05876666666666667,0.21505000000000002,0.19909845956354302,0.2732,0.1055761194029851,0.1763,0.17445,0.19065789473684214,0.75912,0.679536,0.08895,0.218376542471156,0.3757944444444444,0.20191198117244333,0.07655,0.25,0.2075390243902439,-0.0767,0.3857,0.21505000000000002,0.8999,0.13625555555555555,0.49560000000000004,0.27136666666666664,-0.13396666666666665,0.15050379403794037,0.4576,0.4374,0.20156614814814813,0.5267,0.21505000000000005,0.1511821003829873,0.15795228333992878,0.8977,-0.148,0.26336,0.10546666666666667,0.6369,0.17445,0.0772,0.2346315288518739,0.008375,0.3612,0.15832888888888888,0.8476,0.32700216049382713,0.21505000000000005,0.44588,0.0804,0.06465714285714284,0.21505000000000002,0.14994000000000002,0.38893333333333335,0.21619999999999998,0.2732,0.9366,0.14994000000000002,-0.13396666666666665,0.022385714285714287,0.1763,0.202028,-0.11315,-0.23835,-0.18330000000000002,-0.05876666666666667,0.3182,0.0772,0.5267,0.8422499999999999,0.49560000000000004,-0.13396666666666665,0.4404,0.9366,0.53904,0.7184,0.4588,0.45336,-0.18330000000000002,0.8422499999999999,0.21505000000000002,0.07208333333333333,0.7104,0.5165000000000001,0.8611,0.5165000000000001],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778 ...

# %%
# Define the bins, excluding 0 as a separate interval
bins = [-1.0, -0.5, 0.0, 0.5, 1.0]
hist, bin_edges = pd.cut(sentiment_scores_df_new['Average_Sentiment_Score'], bins, right=False, retbins=True)

# Create a DataFrame to display the frequency table
frequency_table = pd.value_counts(hist, sort=False).reset_index()
frequency_table.columns = ['Sentiment_Score_Range', 'Frequency']

# Calculate the proportion of each bin
total_records = len(sentiment_scores_df_new)
frequency_table['Proportion'] = frequency_table['Frequency'] / total_records

# Display the frequency table
print(frequency_table)
# Out:
#   Sentiment_Score_Range  Frequency  Proportion
# 0          [-1.0, -0.5)          0    0.000000
# 1           [-0.5, 0.0)         18    0.118421
# 2            [0.0, 0.5)        109    0.717105
# 3            [0.5, 1.0)         25    0.164474

# %% [markdown]
# # Discord Volume

# %%
# Group the discord messages by day and count the number of discord messages in each day
daily_discord_count = ANT['Content'].resample('D').count()

# Print the daily discord message count
print(daily_discord_count)
# Out:
# Date
# 2022-11-20     7
# 2022-11-21     2
# 2022-11-22     2
# 2022-11-23     1
# 2022-11-24     0
#               ..
# 2023-08-11     3
# 2023-08-12     1
# 2023-08-13     0
# 2023-08-14     8
# 2023-08-15    11
# Freq: D, Name: Content, Length: 269, dtype: int64

# %%
daily_discord_count = daily_discord_count.to_frame(name='Discord Volume').reset_index()

# %%
daily_discord_count
# Out:
#           Date  Discord Volume
# 0   2022-11-20               7
# 1   2022-11-21               2
# 2   2022-11-22               2
# 3   2022-11-23               1
# 4   2022-11-24               0
# ..         ...             ...
# 264 2023-08-11               3
# 265 2023-08-12               1
# 266 2023-08-13               0
# 267 2023-08-14               8
# 268 2023-08-15              11
#
# [269 rows x 2 columns]

# %%
daily_discord_count.to_csv('discord_volume_ant_governance.csv', index=False)

# %%
import plotly.graph_objs as go

# Create a line graph using Plotly
fig = go.Figure()

# Add a line trace to the figure
fig.add_trace(go.Scatter(x=daily_discord_count['Date'], y=daily_discord_count['Discord Volume'], mode='lines'))

# Customize the layout of the figure
fig.update_layout(title='Aragon Discord Daily Message Volume', xaxis_title='Date', yaxis_title='Discord Message Volume')

# Display the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9771c027-39ee-44e1-9bc5-66f4c601bda3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9771c027-39ee-44e1-9bc5-66f4c601bda3")) {                    Plotly.newPlot(                        "9771c027-39ee-44e1-9bc5-66f4c601bda3",                        [{"mode":"lines","x":["2022-11-20T00:00:00","2022-11-21T00:00:00","2022-11-22T00:00:00","2022-11-23T00:00:00","2022-11-24T00:00:00","2022-11-25T00:00:00","2022-11-26T00:00:00","2022-11-27T00:00:00","2022-11-28T00:00:00","2022-11-29T00:00:00","2022-11-30T00:00:00","2022-12-01T00:00:00","2022-12-02T00:00:00","2022-12-03T00:00:00","2022-12-04T00:00:00","2022-12-05T00:00:00","2022-12-06T00:00:00","2022-12-07T00:00:00","2022-12-08T00:00:00","2022-12-09T00:00:00","2022-12-10T00:00:00","2022-12-11T00:00:00","2022-12-12T00:00:00","2022-12-13T00:00:00","2022-12-14T00:00:00","2022-12-15T00:00:00","2022-12-16T00:00:00","2022-12-17T00:00:00","2022-12-18T00:00:00","2022-12-19T00:00:00","2022-12-20T00:00:00","2022-12-21T00:00:00","2022-12-22T00:00:00","2022-12-23T00:00:00","2022-12-24T00:00:00","2022-12-25T00:00:00","2022-12-26T00:00:00","2022-12-27T00:00:00","2022-12-28T00:00:00","2022-12-29T00:00:00","2022-12-30T00:00:00","2022-12-31T00:00:00","2023-01-01T00:00:00","2023-01-02T00:00:00","2023-01-03T00:00:00","2023-01-04T00:00:00","2023-01-05T00:00:00","2023-01-06T00:00:00","2023-01-07T00:00:00","2023-01-08T00:00:00","2023-01-09T00:00:00","2023-01-10T00:00:00","2023-01-11T00:00:00","2023-01-12T00:00:00","2023-01-13T00:00:00","2023-01-14T00:00:00","2023-01-15T00:00:00","2023-01-16T00:00:00","2023-01-17T00:00:00","2023-01-18T00:00:00","2023-01-19T00:00:00","2023-01-20T00:00:00","2023-01-21T00:00:00","2023-01-22T00:00:00","2023-01-23T00:00:00","2023-01-24T00:00:00","2023-01-25T00:00:00","2023-01-26T00:00:00","2023-01-27T00:00:00","2023-01-28T00:00:00","2023-01-29T00:00:00","2023-01-30T00:00:00","2023-01-31T00:00:00","2023-02-01T00:00:00","2023-02-02T00:00:00","2023-02-03T00:00:00","2023-02-04T00:00:00","2023-02-05T00:00:00","2023-02-06T00:00:00","2023-02-07T00:00:00","2023-02-08T00:00:00","2023-02-09T00:00:00","2023-02-10T00:00:00","2023-02-11T00:00:00","2023-02-12T00:00:00","2023-02-13T00:00:00","2023-02-14T00:00:00","2023-02-15T00:00:00","2023-02-16T00:00:00","2023-02-17T00:00:00","2023-02-18T00:00:00","2023-02-19T00:00:00","2023-02-20T00:00:00","2023-02-21T00:00:00","2023-02-22T00:00:00","2023-02-23T00:00:00","2023-02-24T00:00:00","2023-02-25T00:00:00","2023-02-26T00:00:00","2023-02-27T00:00:00","2023-02-28T00:00:00","2023-03-01T00:00:00","2023-03-02T00:00:00","2023-03-03T00:00:00","2023-03-04T00:00:00","2023-03-05T00:00:00","2023-03-06T00:00:00","2023-03-07T00:00:00","2023-03-08T00:00:00","2023-03-09T00:00:00","2023-03-10T00:00:00","2023-03-11T00:00:00","2023-03-12T00:00:00","2023-03-13T00:00:00","2023-03-14T00:00:00","2023-03-15T00:00:00","2023-03-16T00:00:00","2023-03-17T00:00:00","2023-03-18T00:00:00","2023-03-19T00:00:00","2023-03-20T00:00:00","2023-03-21T00:00:00","2023-03-22T00:00:00","2023-03-23T00:00:00","2023-03-24T00:00:00","2023-03-25T00:00:00","2023-03-26T00:00:00","2023-03-27T00:00:00","2023-03-28T00:00:00","2023-03-29T00:00:00","2023-03-30T00:00:00","2023-03-31T00:00:00","2023-04-01T00:00:00","2023-04-02T00:00:00","2023-04-03T00:00:00","2023-04-04T00:00:00","2023-04-05T00:00:00","2023-04-06T00:00:00","2023-04-07T00:00:00","2023-04-08T00:00:00","2023-04-09T00:00:00","2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-14T00:00:00","2023-04-15T00:00:00","2023-04-16T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-22T00:00:00","2023-04-23T00:00:00","2023 ...
